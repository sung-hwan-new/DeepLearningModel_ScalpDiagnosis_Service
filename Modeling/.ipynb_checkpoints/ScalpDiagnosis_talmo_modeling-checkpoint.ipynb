# %% [markdown]
# # 드라이브 마운트 & 언집

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# ./data/training 디렉토리 하위 파일 삭제
shutil.rmtree('./data/train')

# ./data/validation 디렉토리 하위 파일 삭제
shutil.rmtree('./data/val')

# %%
# 디렉토리 생성 (디렉토리 3개로 생성)
# !mkdir -p ./data/train

# !unzip './drive/MyDrive/multi_scalp/train/[원천]탈모_0.양호.zip' -d './data/train/talmo_0'
# !unzip './drive/MyDrive/multi_scalp/train/[원천]탈모_1.경증.zip' -d './data/train/talmo_1'
# !unzip './drive/MyDrive/multi_scalp/train/[원천]탈모_2.중등도.zip' -d './data/train/talmo_1'
# !unzip './drive/MyDrive/multi_scalp/train/[원천]탈모_3.중증.zip' -d './data/train/talmo_2'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604731165776_2_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604731165776_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604736635499_2_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604799766264_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604801095208_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604801296033_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604812524983_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604818190395_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604818190395_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604818376253_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604820736273_2_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604822176790_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604822176790_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604980752614_2_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604980752614_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604980752614_6_BH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604980916260_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604985175899_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604985175899_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604987780060_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604987780060_6_BH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604996547291_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604999276322_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604999276322_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1604999401352_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605070295017_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605073790588_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605074539864_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605086111496_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605155925535_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605155925535_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605163921846_2_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605163921846_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605163921846_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605174481586_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605321007546_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605321007546_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605321007546_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605323204323_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605323204323_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605589267968_3_TH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605589267968_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605857851615_4_LH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1605941800151_5_RH.jpg
#   inflating: ./data/train/talmo_1/9864_A2LEBJJDE001167_1606013094320_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602588207262_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602588207262_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602588207262_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602673178963_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602673178963_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1602736644927_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603351837285_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603435971545_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603449707565_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603449707565_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603520896185_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1603709120875_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604111300885_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604135735206_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604287920366_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604303126300_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604481229557_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604486901109_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604486901109_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604486901109_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604486901109_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604486901109_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604639102105_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604660353130_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604918673168_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604918673168_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1604979254187_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605064924079_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605064924079_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605064924079_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605083798390_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605169895127_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605169895127_6_BH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605262451547_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605262451547_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605500557333_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605515420005_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605613072716_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605613072716_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605670704364_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605670704364_4_LH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605759548860_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605862100980_3_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605930392344_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605955012509_2_TH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1605955012509_5_RH.jpg
#   inflating: ./data/train/talmo_1/9874_A2LEBJJDE00123M_1606112530125_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733741114_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733741114_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733752544_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733815773_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733815773_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733815773_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733826431_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602733863646_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821884746_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821884746_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821918917_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821935605_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821959335_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821959335_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821959335_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821967771_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821967771_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821978287_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821978287_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602821978287_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602906960298_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602906960298_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907038422_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907038422_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907048827_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907048827_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907048827_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907086386_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907098267_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907109462_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907109462_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907109462_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1602907109462_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779641901_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779641901_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779641901_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779658796_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779658796_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779658796_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779672118_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779672118_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779672118_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779672118_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779683588_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779683588_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779704219_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779715215_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779715215_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779742979_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779742979_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779760474_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779760474_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779760474_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779774108_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779774108_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1603779790391_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604192771534_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604192861777_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904798311_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904798311_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904835685_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904856047_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904856047_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904905317_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904942220_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1604904953034_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155088373_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155105216_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155105216_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155119471_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155119471_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155119471_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155133469_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155133469_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155172833_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155185845_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155197321_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605155222564_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489637070_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489679871_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489695369_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489750489_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489750489_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489771259_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605489789090_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943829912_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943853022_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943853022_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943866155_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943866155_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943894370_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943946375_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943968211_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605943968211_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944019061_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944041514_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944041514_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944072943_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944072943_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944072943_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1605944072943_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187039960_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187039960_3_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187039960_4_LH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187039960_5_RH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187039960_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187063059_2_TH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187063059_6_BH.jpg
#   inflating: ./data/train/talmo_1/9887_A2LEBJJDE00066H_1606187076935_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728293299_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728293299_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728308949_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728308949_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728318500_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728318500_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728337457_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728351030_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728351030_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728351030_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728351030_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728358948_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728358948_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728368399_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728368399_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728368399_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728368399_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728380762_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728380762_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728380762_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728388667_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728388667_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728402597_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728402597_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728402597_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728402597_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728402597_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728411160_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728421483_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728421483_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728421483_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728421483_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728421483_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728453133_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728453133_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728460684_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728474945_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728474945_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602728474945_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729003670_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729015949_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729025008_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729055342_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729068960_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729068960_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729068960_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729078907_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729089368_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729089368_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729089368_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729102916_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729102916_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729102916_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729112997_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729112997_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729112997_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729122226_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729122226_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729129371_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729129371_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729129371_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729129371_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729142776_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729142776_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729152117_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729152117_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729167638_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729167638_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729167638_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729167638_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729177103_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729177103_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729184868_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729184868_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729198781_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729212808_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729212808_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729223014_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729228993_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729228993_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729241047_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729241047_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729256353_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729256353_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729268341_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729268341_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729268341_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729268341_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729276358_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729283871_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729283871_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729283871_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729283871_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729283871_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729290984_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729301352_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729301352_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729301352_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729310238_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729310238_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729310238_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729335328_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729335328_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729347625_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729358351_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729386367_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729415423_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729415423_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729431479_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729438041_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729466181_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729466181_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602729466181_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602830274872_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602840125518_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602840125518_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602910523239_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602916499440_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986620058_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986620058_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986620058_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986649701_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986901159_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1602986901159_6_BH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603160446471_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603176763731_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603176763731_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603684610316_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603684610316_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603701822794_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603780506180_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603793302562_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1603965551110_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604024280052_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604479719335_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604479719335_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604543603294_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604737587495_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604737587495_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604737587495_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604737587495_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604808105861_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604990765614_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604990765614_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1604990765614_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605000535016_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605059044239_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605067654297_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605067654297_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605067654297_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605167573717_2_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605167573717_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605167573717_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605167573717_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605175135314_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605243794310_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605243794310_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605318258981_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1605525578512_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1606181702722_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1606181702722_5_RH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1606203543720_3_TH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1606203543720_4_LH.jpg
#   inflating: ./data/train/talmo_1/9905_A2LEBJJDE00042M_1606203543720_5_RH.jpg
# Archive:  ./drive/MyDrive/multi_scalp/train/[원천]탈모_2.중등도.zip
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1603341963457_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1603942963211_3_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1603943094656_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1604540092656_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1604540092656_3_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1604566158514_3_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605242382046_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605242382046_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605242382046_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605242469180_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534137037_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534137037_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534137037_6_BH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534176626_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534176626_6_BH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534189733_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534189733_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534203575_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534218448_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605534218448_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605839548962_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605839548962_3_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605839548962_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1605839548962_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386153203_2_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386153203_3_TH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386153203_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386153203_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386248930_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386248930_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386383334_5_RH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386400774_4_LH.jpg
#   inflating: ./data/train/talmo_1/0013_A2LEBJJDE00060O_1606386451791_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604625006764_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604626189114_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604626540546_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604626540546_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604626540546_6_BH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604626708741_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604627212613_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604627212613_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604627506925_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604627506925_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604627632520_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604631147064_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637199091_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637199091_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637257213_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637257213_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637311267_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637311267_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637340699_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604637429802_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604640074652_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641199658_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641370997_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641629112_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641629112_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641783871_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641918471_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604641918471_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642297431_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642297431_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642492940_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642492940_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642646610_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642646610_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642646610_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642646610_6_BH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642754880_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642754880_6_BH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642895291_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642895291_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604642895291_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644163587_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644247721_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644299259_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644414232_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644528426_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644528426_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644606784_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644798002_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644798002_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604644798002_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645045826_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645219919_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645356697_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645396538_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645497829_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604645589854_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604646238105_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604646238105_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604648614396_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604648809811_6_BH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604649156570_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604649156570_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604649156570_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604650494960_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604839723896_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604892419930_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604892419930_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604901073108_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604901346499_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604904389794_3_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604904527402_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604904799129_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604905768252_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1604905768252_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1606125183231_2_TH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1606125183231_4_LH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1606125183231_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1606125265829_5_RH.jpg
#   inflating: ./data/train/talmo_1/0131_A2LEBJJDE00166C_1606125265829_6_BH.jpg
#   inflating: ./data/train/talmo_1/0177_A2LEBJJDE00152B_1604650515480_4_LH.jpg
#   inflating: ./data/train/talmo_1/0177_A2LEBJJDE00152B_1604650548177_2_TH.jpg
#   inflating: ./data/train/talmo_1/0177_A2LEBJJDE00152B_1604650548177_5_RH.jpg
#   inflating: ./data/train/talmo_1/0177_A2LEBJJDE00152B_1604650548177_6_BH.jpg
#   inflating: ./data/train/talmo_1/0177_A2LEBJJDE00152B_1604650579644_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE00013X_1602906877353_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1602834880782_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1602897441047_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603250832693_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603250832693_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603254466253_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603255068694_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603259809219_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603327202927_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603351116432_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603351116432_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603430474350_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603671423939_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603671423939_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603851259360_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603853146623_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1603950745080_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604295714839_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604457859260_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604552832426_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604553778641_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604559403919_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604715675627_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604715675627_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604717999611_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604717999611_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604718294224_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604718294224_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604718294224_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604718668382_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604718668382_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604719838412_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604725063669_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604725063669_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604725063669_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604725246868_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604884556981_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604974662454_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604977117278_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1604981120969_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605063761598_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605147942600_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605148324310_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605155357608_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605155853936_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605157522593_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605157522593_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605491334794_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605491334794_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605591987678_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605591987678_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605596137471_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605596137471_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605596137471_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605596137471_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605596137471_6_BH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605679528160_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605679528160_4_LH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605679528160_5_RH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605769372405_2_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605769372405_3_TH.jpg
#   inflating: ./data/train/talmo_1/0335_A2LEBJJDE000542_1605769372405_4_LH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1603881075865_2_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793642049_5_RH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793680454_2_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793723902_2_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793723902_4_LH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793723902_5_RH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793799362_2_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793799362_4_LH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793823284_3_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793927978_3_TH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793927978_4_LH.jpg
#   inflating: ./data/train/talmo_1/0425_A2LEBJJDE00079P_1605793974045_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1602840929216_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1602841092035_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603424523940_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603424523940_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603424523940_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603455386219_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603520839287_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603693912025_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603698054380_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603855587378_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603862561025_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1603877304077_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604039910644_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604053019280_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604115986165_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604115986165_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604131366518_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604131366518_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604131366518_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604131366518_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604131366518_6_BH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604215811071_2_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604215811071_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604215811071_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1604216241123_5_RH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1605933890365_4_LH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1605950478740_3_TH.jpg
#   inflating: ./data/train/talmo_1/0556_A2LEBJJDE00041T_1606042708569_4_LH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1603506203689_2_TH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1603512383574_2_TH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605143231448_6_BH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605236200193_4_LH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605241712829_2_TH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605241712829_4_LH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605241712829_5_RH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605252870729_2_TH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605252870729_5_RH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605252870729_6_BH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605316669018_4_LH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605780069578_2_TH.jpg
#   inflating: ./data/train/talmo_1/0616_A2LEBJJDE00004W_1605780069578_5_RH.jpg
# ...
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606453154422_3_TH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606460038990_3_TH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606460038990_4_LH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606528686491_2_TH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606528686491_3_TH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606528686491_5_RH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606528686491_6_BH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606539360321_3_TH.jpg
#   inflating: ./data/train/talmo_2/7126_A2LEBJJDE001534_1606539360321_4_LH.jpg
#   inflating: ./data/train/talmo_2/7168_A2LEBJJDE00124F_1605150213598_2_TH.jpg
#   inflating: ./data/train/talmo_2/7168_A2LEBJJDE00124F_1606357727998_2_TH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602573929741_5_RH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602574080762_2_TH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602574109404_5_RH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602574109404_6_BH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602761218114_3_TH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1602986714584_2_TH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1603262105146_2_TH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1604903499213_5_RH.jpg
#   inflating: ./data/train/talmo_2/7216_A2LEBJJDE000125_1605164631083_2_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604558889316_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604636054784_2_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604636054784_3_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604636054784_6_BH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604641057278_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604662668751_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604723539677_3_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1604830762378_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605164110935_3_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605164110935_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605345522429_2_TH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605345720639_4_LH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605345720639_5_RH.jpg
#   inflating: ./data/train/talmo_2/7229_A2LEBJJDE00142H_1605346012694_4_LH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1603936869400_2_TH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1603936869400_3_TH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1603936869400_6_BH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1604108278103_4_LH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1604109993483_5_RH.jpg
#   inflating: ./data/train/talmo_2/7276_A2LEBJJDE00005P_1604109993483_6_BH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1604917281441_2_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1604917281441_3_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1604927661905_2_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1604927661905_3_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1605004806054_2_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1605004806054_3_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1606280173976_2_TH.jpg
#   inflating: ./data/train/talmo_2/7297_A2LEBJJDE00151I_1606280222809_3_TH.jpg
#   inflating: ./data/train/talmo_2/7338_A2LEBJJDE00006I_1602655551643_2_TH.jpg
#   inflating: ./data/train/talmo_2/7338_A2LEBJJDE00006I_1605684696611_2_TH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00088Q_1604649526815_4_LH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00143A_1602921410558_4_LH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00143A_1604109375139_6_BH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00143A_1604644965282_4_LH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00143A_1604645782906_6_BH.jpg
#   inflating: ./data/train/talmo_2/7366_A2LEBJJDE00143A_1605413675937_3_TH.jpg
#   inflating: ./data/train/talmo_2/7418_A2LEBJJDE000724_1603010941879_5_RH.jpg
#   inflating: ./data/train/talmo_2/7418_A2LEBJJDE000724_1605783565274_3_TH.jpg
#   inflating: ./data/train/talmo_2/7418_A2LEBJJDE000724_1606023645533_3_TH.jpg
#   inflating: ./data/train/talmo_2/7418_A2LEBJJDE000724_1606023645533_6_BH.jpg
#   inflating: ./data/train/talmo_2/7418_A2LEBJJDE00080C_1606115733381_4_LH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605600271772_5_RH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605600271772_6_BH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605600304319_4_LH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605600937383_5_RH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605603047189_3_TH.jpg
#   inflating: ./data/train/talmo_2/7698_A2LEBJJDE00165J_1605603047189_4_LH.jpg
#   inflating: ./data/train/talmo_2/7939_A2LEBJJDE00023R_1602750327345_3_TH.jpg
#   inflating: ./data/train/talmo_2/7939_A2LEBJJDE00023R_1603593145075_6_BH.jpg
#   inflating: ./data/train/talmo_2/7939_A2LEBJJDE00023R_1603606789912_2_TH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE00002B_1603607353904_5_RH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE00002B_1604547817596_4_LH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1603415708784_5_RH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1604810132301_3_TH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1604810132301_5_RH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1605088023137_2_TH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1605323583444_2_TH.jpg
#   inflating: ./data/train/talmo_2/7988_A2LEBJJDE000357_1605328716423_4_LH.jpg
#   inflating: ./data/train/talmo_2/8000_A2LEBJJDE000956_1604640659234_2_TH.jpg
#   inflating: ./data/train/talmo_2/8000_A2LEBJJDE000956_1604640659234_4_LH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1602670712562_3_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1602843195995_3_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1602999779261_3_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1603528050900_3_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1603961953222_2_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1604739657323_3_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1605507970050_2_TH.jpg
#   inflating: ./data/train/talmo_2/8100_A2LEBJJDE00010J_1605507970050_6_BH.jpg
#   inflating: ./data/train/talmo_2/8102_A2LEBJJDE000633_1604050239803_3_TH.jpg
#   inflating: ./data/train/talmo_2/8102_A2LEBJJDE000633_1604050239803_4_LH.jpg
#   inflating: ./data/train/talmo_2/8102_A2LEBJJDE000633_1606559306369_4_LH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00011C_1605869081351_3_TH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604106622137_2_TH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604106622137_5_RH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604107729838_5_RH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604479316809_2_TH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604538299454_3_TH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604720444982_4_LH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1604720444982_5_RH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1606048055965_4_LH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1606048055965_5_RH.jpg
#   inflating: ./data/train/talmo_2/8146_A2LEBJJDE00148A_1606387812977_4_LH.jpg
#   inflating: ./data/train/talmo_2/8212_A2LEBJJDE00070I_1604050543195_5_RH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1605149875297_5_RH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1605149916067_5_RH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1605578895096_2_TH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1605578895096_3_TH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1605835791036_5_RH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1606192512387_2_TH.jpg
#   inflating: ./data/train/talmo_2/8224_A2LEBJJDE000448_1606192512387_3_TH.jpg
#   inflating: ./data/train/talmo_2/8281_A2LEBJJDE00055U_1606037545052_2_TH.jpg
#   inflating: ./data/train/talmo_2/8297_A2LEBJJDE001076_1602831199836_4_LH.jpg
#   inflating: ./data/train/talmo_2/8297_A2LEBJJDE001076_1602831199836_6_BH.jpg
#   inflating: ./data/train/talmo_2/8297_A2LEBJJDE001076_1605770252526_5_RH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1602754891594_3_TH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1602832636769_5_RH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1603426733060_2_TH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1603426733060_4_LH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1603426733060_5_RH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1603450866194_3_TH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1606015178659_4_LH.jpg
#   inflating: ./data/train/talmo_2/8337_A2LEBJJDE00109R_1606015178659_5_RH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1603848827473_2_TH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1604365560793_3_TH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1604815778504_2_TH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1605143349827_4_LH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1605143349827_5_RH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1605759735897_5_RH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1606007849927_3_TH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1606015457272_4_LH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1606373599111_2_TH.jpg
#   inflating: ./data/train/talmo_2/8366_A2LEBJJDE00196T_1606373599111_3_TH.jpg
#   inflating: ./data/train/talmo_2/8606_A2LEBJJDE00155P_1606460314634_2_TH.jpg
#   inflating: ./data/train/talmo_2/8606_A2LEBJJDE00155P_1606461140797_2_TH.jpg
#   inflating: ./data/train/talmo_2/8606_A2LEBJJDE00155P_1606461140797_3_TH.jpg
#   inflating: ./data/train/talmo_2/8781_A2LEBJJDE000906_1604731126441_2_TH.jpg
#   inflating: ./data/train/talmo_2/8814_A2LEBJJDE00118S_1602847071581_5_RH.jpg
#   inflating: ./data/train/talmo_2/8814_A2LEBJJDE00118S_1604122597619_5_RH.jpg
#   inflating: ./data/train/talmo_2/8814_A2LEBJJDE00118S_1605154748470_2_TH.jpg
#   inflating: ./data/train/talmo_2/8833_A2LEBJJDE00156I_1606015286101_5_RH.jpg
#   inflating: ./data/train/talmo_2/8833_A2LEBJJDE00156I_1606038487891_2_TH.jpg
#   inflating: ./data/train/talmo_2/8896_A2LEBJJDE001807_1605765040606_2_TH.jpg
#   inflating: ./data/train/talmo_2/8896_A2LEBJJDE001807_1606527094132_5_RH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1603515220792_3_TH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1603515220792_6_BH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1604284840904_6_BH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1604640737005_5_RH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1604910331866_2_TH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1604910331866_3_TH.jpg
#   inflating: ./data/train/talmo_2/9202_A2LEBJJDE00082X_1605537248911_3_TH.jpg
#   inflating: ./data/train/talmo_2/9296_A2LEBJJDE00073W_1604635457527_3_TH.jpg
#   inflating: ./data/train/talmo_2/9296_A2LEBJJDE00073W_1604650651869_3_TH.jpg
#   inflating: ./data/train/talmo_2/9316_A2LEBJJDE00034E_1605835476700_2_TH.jpg
#   inflating: ./data/train/talmo_2/9338_A2LEBJJDE00101D_1606570081727_4_LH.jpg
#   inflating: ./data/train/talmo_2/9356_A2LEBJJDE001443_1602834669925_5_RH.jpg
#   inflating: ./data/train/talmo_2/9356_A2LEBJJDE001443_1602901847172_5_RH.jpg
#   inflating: ./data/train/talmo_2/9356_A2LEBJJDE00192M_1605264142586_3_TH.jpg
#   inflating: ./data/train/talmo_2/9400_A2LEBJJDE00078W_1604034884393_3_TH.jpg
#   inflating: ./data/train/talmo_2/9400_A2LEBJJDE00078W_1604034965363_3_TH.jpg
#   inflating: ./data/train/talmo_2/9414_A2LEBJJDE00033L_1605343646436_2_TH.jpg
#   inflating: ./data/train/talmo_2/9414_A2LEBJJDE00033L_1605343646436_3_TH.jpg
#   inflating: ./data/train/talmo_2/9414_A2LEBJJDE00033L_1605344984157_3_TH.jpg
#   inflating: ./data/train/talmo_2/9414_A2LEBJJDE00033L_1605578395330_4_LH.jpg
#   inflating: ./data/train/talmo_2/9447_A2LEBJJDE001951_1604051099190_4_LH.jpg
#   inflating: ./data/train/talmo_2/9447_A2LEBJJDE001951_1606018627154_2_TH.jpg
#   inflating: ./data/train/talmo_2/9447_A2LEBJJDE001951_1606209170559_3_TH.jpg
#   inflating: ./data/train/talmo_2/9447_A2LEBJJDE001951_1606304517283_2_TH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1602651795554_4_LH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1603081813460_5_RH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1605683475333_2_TH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1605683475333_4_LH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1605683475333_6_BH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1606393633690_5_RH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1606393633690_6_BH.jpg
#   inflating: ./data/train/talmo_2/9527_A2LEBJJDE00110E_1606552143878_5_RH.jpg
#   inflating: ./data/train/talmo_2/9578_A2LEBJJDE00105K_1604647957078_2_TH.jpg
#   inflating: ./data/train/talmo_2/9578_A2LEBJJDE00105K_1605330285368_4_LH.jpg
#   inflating: ./data/train/talmo_2/9578_A2LEBJJDE00105K_1605430766134_5_RH.jpg
#   inflating: ./data/train/talmo_2/9817_A2LEBJJDE00193F_1604040767699_3_TH.jpg
#   inflating: ./data/train/talmo_2/9817_A2LEBJJDE00193F_1604113441741_3_TH.jpg
#   inflating: ./data/train/talmo_2/9817_A2LEBJJDE00193F_1604120926523_5_RH.jpg
#   inflating: ./data/train/talmo_2/9817_A2LEBJJDE00193F_1605151570942_4_LH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1602913005874_5_RH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1603509637675_3_TH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1603962195906_2_TH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1604108559438_5_RH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1604111873333_5_RH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1604719747290_2_TH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1604719747290_3_TH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1605232595266_2_TH.jpg
#   inflating: ./data/train/talmo_2/9864_A2LEBJJDE001167_1605232595266_6_BH.jpg
#   inflating: ./data/train/talmo_2/9874_A2LEBJJDE00123M_1604481229557_2_TH.jpg
#   inflating: ./data/train/talmo_2/9874_A2LEBJJDE00123M_1605759548860_2_TH.jpg
#   inflating: ./data/train/talmo_2/9874_A2LEBJJDE00123M_1605759548860_3_TH.jpg
#   inflating: ./data/train/talmo_2/9887_A2LEBJJDE00066H_1602907098267_3_TH.jpg
#   inflating: ./data/train/talmo_2/9887_A2LEBJJDE00066H_1605155133469_6_BH.jpg
#   inflating: ./data/train/talmo_2/9905_A2LEBJJDE00042M_1602729142776_4_LH.jpg
#   inflating: ./data/train/talmo_2/9905_A2LEBJJDE00042M_1602729347625_4_LH.jpg
#   inflating: ./data/train/talmo_2/9905_A2LEBJJDE00042M_1604108127168_4_LH.jpg
#   inflating: ./data/train/talmo_2/9905_A2LEBJJDE00042M_1606541098293_2_TH.jpg

# %%
# 디렉토리 생성 (디렉토리 3개로 생성)
# !mkdir -p ./data/val

# !unzip './drive/MyDrive/multi_scalp/val/[원천]탈모_0.양호.zip' -d './data/val/talmo_0'
# !unzip './drive/MyDrive/multi_scalp/val/[원천]탈모_1.경증.zip' -d './data/val/talmo_1'
# !unzip './drive/MyDrive/multi_scalp/val/[원천]탈모_2.중등도.zip' -d './data/val/talmo_1'
# !unzip './drive/MyDrive/multi_scalp/val/[원천]탈모_3.중증.zip' -d './data/val/talmo_2'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./data/val/talmo_1/0556_A2LEBJJDE00041T_1606642579459_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606536965136_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538123209_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538123209_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538425215_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538425215_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538584363_2_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606538584363_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606612222288_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606618983145_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606618983145_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606618983145_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606618983145_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606626618637_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606630006599_2_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606630006599_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606630006599_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606639171954_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606639171954_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606646037046_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606646037046_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606646037046_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606706413990_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606706638030_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606707119986_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606715499277_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606981331034_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1606981331034_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1607650278087_6_BH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1607650426514_3_TH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1607650426514_4_LH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1607650426514_5_RH.jpg
#   inflating: ./data/val/talmo_1/0616_A2LEBJJDE00004W_1607650932662_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535063640_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535106640_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535148302_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535597454_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535616973_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535825432_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535825432_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535825432_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535884561_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535884561_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535884561_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606535911412_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606536114605_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613775933_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613775933_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613775933_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613775933_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613819548_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613819548_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613865854_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613865854_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613914470_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613914470_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613953133_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606613953133_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606614396591_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606614669722_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606614669722_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606614669722_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606618240347_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648231485_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648650605_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648969671_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648983375_2_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648983375_3_TH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606648983375_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606649812559_4_LH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606649812559_5_RH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606649812559_6_BH.jpg
#   inflating: ./data/val/talmo_1/0617_A2LEBJJDE000815_1606690340913_4_LH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606710930515_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711301891_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711378217_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711378217_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711410681_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711410681_4_LH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711433638_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606711433638_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606712038427_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606712038427_4_LH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606712038427_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606712038427_6_BH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606712865386_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606713494324_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606713761766_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606721399197_4_LH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606723340875_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606724706900_4_LH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606725121275_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606785431951_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606785645113_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606811935169_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606811935169_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606883472149_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606884569658_6_BH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1606889175619_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607046824526_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607046824526_6_BH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607074708384_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607131725416_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607140759189_2_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607140759189_6_BH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607230972651_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607247913309_3_TH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607247913309_5_RH.jpg
#   inflating: ./data/val/talmo_1/0643_A2LEBJJDE00048F_1607247913309_6_BH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606285638533_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606285638533_6_BH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606302929353_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606302929353_5_RH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606367405148_3_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606367405148_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606367405148_5_RH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606367405148_6_BH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606369412116_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606370189672_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606370189672_5_RH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606453818107_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606454573057_3_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606459085863_2_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606459085863_3_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606459085863_5_RH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606459085863_6_BH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606460066118_4_LH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606472189238_2_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606534642598_2_TH.jpg
#   inflating: ./data/val/talmo_1/0663_A2LEBJJDE001716_1606790518260_5_RH.jpg
#   inflating: ./data/val/talmo_1/0703_A2LEBJJDE000774_1606364213492_2_TH.jpg
#   inflating: ./data/val/talmo_1/0703_A2LEBJJDE000774_1606364765909_4_LH.jpg
#   inflating: ./data/val/talmo_1/0703_A2LEBJJDE000774_1606364765909_5_RH.jpg
#   inflating: ./data/val/talmo_1/0703_A2LEBJJDE000774_1606364765909_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606704346716_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606704583492_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606706633707_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606707362028_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606881860916_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606882399166_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606882399166_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606883509391_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606883509391_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606883509391_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606883979785_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1606883979785_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607483171676_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607483171676_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607488698546_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607489135094_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607492696385_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607492696385_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607492696385_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495046489_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495046489_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495087368_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495087368_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495207485_2_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495257185_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495295261_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495318032_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495318032_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495355285_4_LH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495370588_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495393951_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495393951_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495408384_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495591168_5_RH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495591168_6_BH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1607495606033_3_TH.jpg
#   inflating: ./data/val/talmo_1/0715_A2LEBJJDE00175D_1608093008046_4_LH.jpg
#   inflating: ./data/val/talmo_1/0733_A2LEBJJDE000084_1606386153944_6_BH.jpg
#   inflating: ./data/val/talmo_1/0733_A2LEBJJDE000084_1606465117663_3_TH.jpg
#   inflating: ./data/val/talmo_1/0733_A2LEBJJDE000084_1606465117663_4_LH.jpg
#   inflating: ./data/val/talmo_1/0733_A2LEBJJDE000084_1606465117663_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606294590102_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606541360657_3_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606541360657_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606541360657_5_RH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606632858500_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606632858500_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606646642535_5_RH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606809683084_5_RH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606809683084_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1606990357239_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607171495642_3_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607171495642_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607171495642_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607236479272_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607242295982_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607242295982_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607335401960_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607504594418_5_RH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607507838495_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607507838495_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607508933367_4_LH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607510483842_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607591649777_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607591649777_6_BH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607687053478_3_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1607687053478_5_RH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1608112311709_2_TH.jpg
#   inflating: ./data/val/talmo_1/0770_A2LEBJJDE000865_1608112311709_6_BH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606288141868_3_TH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606288141868_4_LH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606288141868_5_RH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606288141868_6_BH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606303857175_4_LH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606378773510_2_TH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606441090900_2_TH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606441090900_3_TH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606441090900_5_RH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606441090900_6_BH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606474235825_6_BH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606552739347_5_RH.jpg
#   inflating: ./data/val/talmo_1/0888_A2LEBJJDE001948_1606552739347_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606461468041_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606463722268_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606463722268_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606463722268_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606463722268_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606464358350_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606464358350_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606469199159_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606469199159_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606613174109_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606618342720_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606618342720_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606635170363_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606727499118_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606727499118_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606969026065_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606969277490_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606983317182_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1606983317182_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607051982826_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607051982826_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607054441808_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607054441808_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607067613624_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607067613624_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607130492081_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607138507507_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607142984268_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607144873059_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607144873059_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607144873059_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607146090052_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607146277539_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607150110582_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607155989688_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607155989688_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607160663768_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607160663768_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607160663768_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607228112932_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607232084094_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607235034825_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607241934845_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607242741157_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607242741157_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607251300940_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607260775335_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607260775335_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607260775335_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607334404102_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607334404102_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607487582670_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607563613477_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607563613477_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607563613477_6_BH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607577803550_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607577803550_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607577803550_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607577803550_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607579198546_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607579277867_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607579277867_5_RH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607579648166_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607579648166_3_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607580145129_2_TH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607580145129_4_LH.jpg
#   inflating: ./data/val/talmo_1/1069_A2LEBJJDE00094D_1607759160021_2_TH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606614995342_4_LH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615012438_5_RH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615012438_6_BH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615040316_6_BH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615069922_4_LH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615069922_5_RH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615083843_2_TH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615083843_6_BH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615114818_5_RH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1606615114818_6_BH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1607653080984_4_LH.jpg
#   inflating: ./data/val/talmo_1/1071_A2LEBJJDE00173R_1607653080984_5_RH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1606356335083_2_TH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1606356335083_4_LH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1606356335083_5_RH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1606716195315_4_LH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1606795511098_5_RH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607044953509_2_TH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607044953509_6_BH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607743003083_4_LH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607743003083_5_RH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607743004571_2_TH.jpg
#   inflating: ./data/val/talmo_1/1080_A2LEBJJDE00092R_1607743004571_4_LH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606444206037_2_TH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606444434732_4_LH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606444614396_5_RH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606452766065_3_TH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606458343486_3_TH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606459104093_2_TH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606459104093_4_LH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606459104093_5_RH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606459104093_6_BH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606708721621_4_LH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606730197812_4_LH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606730197812_6_BH.jpg
#   inflating: ./data/val/talmo_1/1142_A2LEBJJDE00024K_1606730703656_2_TH.jpg
#   inflating: ./data/val/talmo_1/1145_A2LEBJJDE00119L_1606737153534_4_LH.jpg
#   inflating: ./data/val/talmo_1/1145_A2LEBJJDE00119L_1606737153534_5_RH.jpg
#   inflating: ./data/val/talmo_1/1145_A2LEBJJDE00119L_1606743621823_3_TH.jpg
#   inflating: ./data/val/talmo_1/1145_A2LEBJJDE00119L_1606790058215_3_TH.jpg
#   inflating: ./data/val/talmo_1/1145_A2LEBJJDE00119L_1606790058215_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606618006075_2_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803458878_2_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803470768_3_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803470768_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803500543_3_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803500543_4_LH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803500543_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803535623_4_LH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803579949_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803601148_6_BH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803677501_3_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803850548_2_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606803850548_4_LH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606807803311_2_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606874898170_4_LH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1606874898170_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1607400260800_3_TH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1607400260800_4_LH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1607403179924_5_RH.jpg
#   inflating: ./data/val/talmo_1/1195_A2LEBJJDE00197M_1607494717681_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607650964355_6_BH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607651241021_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607653151108_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607653151108_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607653151108_6_BH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607676126583_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607732871026_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607732871026_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607735094244_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607735094244_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607737196000_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607737196000_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607737254620_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607747647881_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607747647881_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607750972382_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607750972382_6_BH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607751191710_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607754391817_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607754391817_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607754391817_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607907871439_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1607929313387_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1608009022913_4_LH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1608108331367_2_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1608108331367_3_TH.jpg
#   inflating: ./data/val/talmo_1/1221_A1LCAIHDH00009X_1608108331367_5_RH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606293544841_2_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606293544841_4_LH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606298001021_5_RH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606298946648_3_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606362885563_2_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606363684125_2_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606363684125_3_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606369307374_5_RH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606369773349_4_LH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606370459379_3_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606376451079_2_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606376716813_4_LH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606376716813_6_BH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606378724959_2_TH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606378939107_4_LH.jpg
#   inflating: ./data/val/talmo_1/1407_A2LEBJJDE001258_1606378939107_5_RH.jpg
#   inflating: ./data/val/talmo_1/1459_A2LEBJJDE00025D_1606551882057_2_TH.jpg
#   inflating: ./data/val/talmo_1/1459_A2LEBJJDE00025D_1606551882057_5_RH.jpg
#   inflating: ./data/val/talmo_1/1459_A2LEBJJDE00025D_1606555774862_5_RH.jpg
#   inflating: ./data/val/talmo_1/1534_A2LEBJJDE00133G_1606983127987_3_TH.jpg
#   inflating: ./data/val/talmo_1/1534_A2LEBJJDE00133G_1606983127987_4_LH.jpg
#   inflating: ./data/val/talmo_1/1534_A2LEBJJDE00133G_1607159339418_3_TH.jpg
#   inflating: ./data/val/talmo_1/1534_A2LEBJJDE00133G_1607159339418_6_BH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606288665930_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606293004980_5_RH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606293963079_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606300132459_4_LH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606370129938_4_LH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606370129938_5_RH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606372448844_5_RH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606379590198_2_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606379590198_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606528911479_2_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606528911479_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606543603622_5_RH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606546129335_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606546925555_6_BH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606633346739_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606633346739_4_LH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606640132144_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606641282867_3_TH.jpg
#   inflating: ./data/val/talmo_1/1743_A2LEBJJDE00031Z_1606641282867_4_LH.jpg
#   inflating: ./data/val/talmo_1/1940_A2LEBJJDE000307_1606367981525_3_TH.jpg
#   inflating: ./data/val/talmo_1/1940_A2LEBJJDE000307_1606367981525_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607385645715_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607386597411_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607386597411_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607387267969_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607387267969_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607387558160_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390435421_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390670982_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390670982_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390670982_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390923885_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607390923885_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607391188960_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607391188960_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607402991378_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607403351651_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404179787_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404439709_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404439709_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404669792_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404669792_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607404669792_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405010068_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405010068_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405250890_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405250890_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405806463_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405806463_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607405806463_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406138474_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406465440_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406465440_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406465440_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406742804_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406989128_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406989128_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406989128_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607406989128_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407261024_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407261024_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407261024_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407261024_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407525563_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407796673_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407796673_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407796673_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607407796673_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607488889623_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607488889623_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607489141031_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607489141031_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607489450814_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607489450814_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607489708097_5_RH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607490141759_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607490469182_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607490469182_4_LH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607490469182_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607491021601_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1607491021601_6_BH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1608164049333_2_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1608164049333_3_TH.jpg
#   inflating: ./data/val/talmo_1/1963_A2LCBJCAC00003V_1608164049333_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606376891358_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606523468395_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606523468395_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606523468395_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606529971784_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606530293213_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606531718504_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606531718504_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606532311197_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606532625512_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606532625512_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606532937413_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606533246299_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606533246299_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606533246299_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606541644350_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606541644350_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606633683599_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606633683599_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606633974009_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606633974009_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606634600229_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606634600229_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606635160829_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606635594657_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606635594657_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606636964183_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606638277742_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606638553023_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606702229254_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606704296508_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606711074193_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723327491_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723327491_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723327491_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723327491_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723596854_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723596854_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723596854_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606723596854_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606724235063_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606724505326_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606724505326_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606730751136_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606730751136_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606875378395_2_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606875378395_3_TH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606875665672_5_RH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606881143970_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1606892669985_6_BH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1607254439020_4_LH.jpg
#   inflating: ./data/val/talmo_1/1981_A2LEBJJDE001493_1607254453752_6_BH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370150925_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370150925_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370165912_2_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370165912_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370269541_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370329963_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606370344342_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442117868_3_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442117868_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442134951_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442151346_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442184914_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442203329_3_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442203329_5_RH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442216760_2_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442216760_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442229412_3_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442229412_4_LH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442242573_3_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442255563_2_TH.jpg
#   inflating: ./data/val/talmo_1/1983_A2LEBJJDE00188L_1606442255563_5_RH.jpg
#   inflating: ./data/val/talmo_1/2023_A2LEBJJDE00018X_1607569187021_2_TH.jpg
#   inflating: ./data/val/talmo_1/2023_A2LEBJJDE00018X_1607569187021_4_LH.jpg
#   inflating: ./data/val/talmo_1/2023_A2LEBJJDE00018X_1607569187021_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625470409_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625507169_3_TH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625534083_3_TH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625534083_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625588428_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625603337_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625603337_6_BH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625617402_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625617402_6_BH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625629144_5_RH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625641285_3_TH.jpg
#   inflating: ./data/val/talmo_1/2032_A2LEBJJDE00152B_1606625653767_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653081526_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653102516_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653127989_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653143869_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653158398_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653158398_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653158398_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653158398_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653179101_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653179101_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653219066_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653219066_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653269598_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653342664_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653362860_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653404889_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653439648_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653439648_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653439648_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653460305_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653798431_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653798431_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653811742_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653843545_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653843545_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653869548_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653894298_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653894298_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653950589_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653950589_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606653982164_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606654008416_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606654132881_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655319362_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655319362_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655331458_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655331458_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655331458_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655359883_4_LH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655417392_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655429233_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655455998_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655455998_5_RH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655480965_2_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655480965_3_TH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655480965_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655545430_6_BH.jpg
#   inflating: ./data/val/talmo_1/2278_A2LEBJJDE00181Z_1606655558458_3_TH.jpg
# ...
#   inflating: ./data/val/talmo_2/1981_A2LEBJJDE001493_1607254453752_5_RH.jpg
#   inflating: ./data/val/talmo_2/2032_A2LEBJJDE00152B_1606625707909_3_TH.jpg
#   inflating: ./data/val/talmo_2/2278_A2LEBJJDE00181Z_1606653102516_2_TH.jpg
#   inflating: ./data/val/talmo_2/2278_A2LEBJJDE00181Z_1606653102516_3_TH.jpg
#   inflating: ./data/val/talmo_2/2278_A2LEBJJDE00181Z_1606653269598_3_TH.jpg
#   inflating: ./data/val/talmo_2/2327_A2LEBJJDE00091Y_1608604867405_2_TH.jpg
#   inflating: ./data/val/talmo_2/2522_A2LEBJJDE00014Q_1606708357940_5_RH.jpg
#   inflating: ./data/val/talmo_2/2720_A2LEBJJDE000401_1606631196920_3_TH.jpg
#   inflating: ./data/val/talmo_2/2720_A2LEBJJDE000401_1607673538469_5_RH.jpg
#   inflating: ./data/val/talmo_2/2820_A2LEBJJDE00179K_1607493641101_2_TH.jpg
#   inflating: ./data/val/talmo_2/2820_A2LEBJJDE00179K_1607493641101_5_RH.jpg
#   inflating: ./data/val/talmo_2/2996_A2LEBJJDE00083Q_1606632250811_3_TH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1607661618039_2_TH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1607679834651_4_LH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608001067463_6_BH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608091591133_4_LH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608199455814_3_TH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608356522126_5_RH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608368224457_2_TH.jpg
#   inflating: ./data/val/talmo_2/3006_A1LCAIHDH00007C_1608372646964_4_LH.jpg
#   inflating: ./data/val/talmo_2/3216_A1LCAIHDH00006J_1608350715381_3_TH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608253733960_4_LH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608264133642_2_TH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608349584972_4_LH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608358778385_4_LH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608358778385_5_RH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608428605554_4_LH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608428605554_5_RH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608713043136_6_BH.jpg
#   inflating: ./data/val/talmo_2/3263_A1LCAIHDH00014R_1608713345405_3_TH.jpg
#   inflating: ./data/val/talmo_2/3269_A2LEBJJDE00096Y_1608083270588_4_LH.jpg
#   inflating: ./data/val/talmo_2/3677_A2LEBJJDE00087X_1607678220579_2_TH.jpg
#   inflating: ./data/val/talmo_2/3755_A2LEBJJDE001857_1608269670505_2_TH.jpg
#   inflating: ./data/val/talmo_2/3755_A2LEBJJDE001857_1608270204373_2_TH.jpg
#   inflating: ./data/val/talmo_2/3937_A2LEBJJDE00046T_1607646935508_6_BH.jpg
#   inflating: ./data/val/talmo_2/3977_A2LCBJCAC000073_1608010201508_4_LH.jpg
#   inflating: ./data/val/talmo_2/3977_A2LCBJCAC000073_1608010201508_5_RH.jpg
#   inflating: ./data/val/talmo_2/3977_A2LCBJCAC000073_1608010315989_3_TH.jpg
#   inflating: ./data/val/talmo_2/4002_A2LEBJJDE00137N_1606622715195_3_TH.jpg
#   inflating: ./data/val/talmo_2/4015_A2LEBJJDE00150P_1606702157195_5_RH.jpg
#   inflating: ./data/val/talmo_2/4015_A2LEBJJDE00150P_1606702510460_4_LH.jpg
#   inflating: ./data/val/talmo_2/4015_A2LEBJJDE00150P_1606702995620_5_RH.jpg
#   inflating: ./data/val/talmo_2/4015_A2LEBJJDE00150P_1606707924963_3_TH.jpg
#   inflating: ./data/val/talmo_2/4015_A2LEBJJDE00150P_1606708262417_3_TH.jpg
#   inflating: ./data/val/talmo_2/4133_A1LCAIHDH000035_1608692439802_5_RH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607649162583_4_LH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607649398445_4_LH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607649398445_5_RH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607650630799_4_LH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607651952100_2_TH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607651952100_4_LH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607651952100_6_BH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607652115284_2_TH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607652115284_4_LH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607652749194_2_TH.jpg
#   inflating: ./data/val/talmo_2/4162_A2LEBJJDE00013X_1607652989908_4_LH.jpg
#   inflating: ./data/val/talmo_2/4267_A1LCAIHDH00016D_1607854439118_5_RH.jpg
#   inflating: ./data/val/talmo_2/4307_A2LEBJJDE000683_1606653808526_2_TH.jpg
#   inflating: ./data/val/talmo_2/4307_A2LEBJJDE000683_1606655825088_3_TH.jpg
#   inflating: ./data/val/talmo_2/4307_A2LEBJJDE000683_1606659753305_5_RH.jpg
#   inflating: ./data/val/talmo_2/4307_A2LEBJJDE000683_1606660270348_2_TH.jpg
#   inflating: ./data/val/talmo_2/4370_A1LCAIHDH00005Q_1607837222616_5_RH.jpg
#   inflating: ./data/val/talmo_2/4795_A2LEBJJDE00113S_1606733681964_3_TH.jpg
#   inflating: ./data/val/talmo_2/4810_A2LEBJJDE00177Y_1607586271628_2_TH.jpg
#   inflating: ./data/val/talmo_2/4810_A2LEBJJDE00177Y_1607586327437_5_RH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607657423959_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607762222384_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607764594057_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607766755480_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607843210509_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607846567323_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1607855545554_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608001420956_4_LH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608010320782_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608021750350_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608024397888_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608029101918_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608089398540_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608090607468_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608096823067_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608097721741_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608098141975_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608100761430_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608189952405_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608199637630_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608345216066_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608345760894_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608346586976_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608350885006_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608354184373_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608354516482_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608355030996_2_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608355030996_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608355030996_4_LH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608355030996_5_RH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608358818279_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608365350066_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608369268238_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608370208866_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608451612533_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608455283197_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608455660056_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608524873531_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608604797637_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608605085797_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608608608230_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608614468067_3_TH.jpg
#   inflating: ./data/val/talmo_2/4970_A1LCAIHDH00010K_1608634292961_3_TH.jpg
#   inflating: ./data/val/talmo_2/5030_A2LEBJJDE00182S_1606888007600_3_TH.jpg
#   inflating: ./data/val/talmo_2/5030_A2LEBJJDE00182S_1606888198014_4_LH.jpg
#   inflating: ./data/val/talmo_2/5030_A2LEBJJDE00186Z_1606741330972_3_TH.jpg
#   inflating: ./data/val/talmo_2/5415_A2LEBJJDE00032S_1606716474440_5_RH.jpg
#   inflating: ./data/val/talmo_2/5619_A2LEBJJDE00002B_1606701789646_5_RH.jpg
#   inflating: ./data/val/talmo_2/5619_A2LEBJJDE00002B_1606721922192_5_RH.jpg
#   inflating: ./data/val/talmo_2/5619_A2LEBJJDE00002B_1607336309453_5_RH.jpg
#   inflating: ./data/val/talmo_2/5619_A2LEBJJDE00002B_1608432384559_5_RH.jpg
#   inflating: ./data/val/talmo_2/5619_A2LEBJJDE00002B_1608432384559_6_BH.jpg
#   inflating: ./data/val/talmo_2/5939_A2LEBJJDE00129F_1606621814266_4_LH.jpg
#   inflating: ./data/val/talmo_2/5939_A2LEBJJDE00129F_1606621814266_5_RH.jpg
#   inflating: ./data/val/talmo_2/6367_A2LEBJJDE00038L_1607575368063_5_RH.jpg
#   inflating: ./data/val/talmo_2/6437_A1LCAIHDH00019R_1607650024097_3_TH.jpg
#   inflating: ./data/val/talmo_2/6437_A1LCAIHDH00019R_1607650207709_3_TH.jpg
#   inflating: ./data/val/talmo_2/6437_A1LCAIHDH00019R_1607650685169_3_TH.jpg
#   inflating: ./data/val/talmo_2/6437_A1LCAIHDH00019R_1607650864939_5_RH.jpg
#   inflating: ./data/val/talmo_2/6440_A2LEBJJDE001352_1607760151041_3_TH.jpg
#   inflating: ./data/val/talmo_2/6440_A2LEBJJDE001352_1608094352794_4_LH.jpg
#   inflating: ./data/val/talmo_2/6440_A2LEBJJDE001352_1608363926099_4_LH.jpg
#   inflating: ./data/val/talmo_2/6440_A2LEBJJDE001352_1608615960362_2_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607316533799_3_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607591523544_2_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607830769658_2_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607830769658_6_BH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607830869766_2_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607830869766_3_TH.jpg
#   inflating: ./data/val/talmo_2/6570_A2LEBJJDE001675_1607830962590_3_TH.jpg
#   inflating: ./data/val/talmo_2/6818_A2LEBJJDE00170D_1606633465659_2_TH.jpg
#   inflating: ./data/val/talmo_2/6818_A2LEBJJDE00170D_1606633465659_3_TH.jpg
#   inflating: ./data/val/talmo_2/7297_A2LEBJJDE00151I_1606700272879_3_TH.jpg
#   inflating: ./data/val/talmo_2/7297_A2LEBJJDE00151I_1606700316948_4_LH.jpg
#   inflating: ./data/val/talmo_2/7297_A2LEBJJDE00151I_1606700972009_5_RH.jpg
#   inflating: ./data/val/talmo_2/7297_A2LEBJJDE00151I_1606702377336_4_LH.jpg
#   inflating: ./data/val/talmo_2/7338_A2LEBJJDE00006I_1606707144336_5_RH.jpg
#   inflating: ./data/val/talmo_2/7366_A2LEBJJDE00088Q_1607648537466_5_RH.jpg
#   inflating: ./data/val/talmo_2/7584_A2LEBJJDE00189E_1607701705706_5_RH.jpg
#   inflating: ./data/val/talmo_2/7670_A1LCAIHDH000126_1607569556516_3_TH.jpg
#   inflating: ./data/val/talmo_2/7670_A1LCAIHDH000126_1608793272671_3_TH.jpg
#   inflating: ./data/val/talmo_2/7851_A2LEBJJDE00074P_1606644420725_2_TH.jpg
#   inflating: ./data/val/talmo_2/7851_A2LEBJJDE00074P_1608359740234_2_TH.jpg
#   inflating: ./data/val/talmo_2/7985_A1LCAIHDH00011D_1608459833021_3_TH.jpg
#   inflating: ./data/val/talmo_2/8212_A2LEBJJDE00070I_1606706873175_2_TH.jpg
#   inflating: ./data/val/talmo_2/8212_A2LEBJJDE00070I_1606706873175_3_TH.jpg
#   inflating: ./data/val/talmo_2/8281_A2LEBJJDE00055U_1606730030225_2_TH.jpg
#   inflating: ./data/val/talmo_2/8281_A2LEBJJDE00055U_1607059062900_2_TH.jpg
#   inflating: ./data/val/talmo_2/8297_A2LEBJJDE001076_1607322755114_3_TH.jpg
#   inflating: ./data/val/talmo_2/8297_A2LEBJJDE001076_1607322755114_4_LH.jpg
#   inflating: ./data/val/talmo_2/8297_A2LEBJJDE001076_1607323391689_6_BH.jpg
#   inflating: ./data/val/talmo_2/8297_A2LEBJJDE001076_1608171374432_2_TH.jpg
#   inflating: ./data/val/talmo_2/8366_A2LEBJJDE00039E_1607499549770_2_TH.jpg
#   inflating: ./data/val/talmo_2/8366_A2LEBJJDE00039E_1607499549770_3_TH.jpg
#   inflating: ./data/val/talmo_2/8366_A2LEBJJDE00039E_1607499549770_4_LH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608698657423_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608698882924_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608698934289_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699073510_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699208765_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699366426_2_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699366426_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699366426_4_LH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699366426_5_RH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699366426_6_BH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608699400127_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608700484067_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703191646_3_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703191646_4_LH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703191646_5_RH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703382417_2_TH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703382417_4_LH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608703382417_5_RH.jpg
#   inflating: ./data/val/talmo_2/8802_A2LEBJJDE00174K_1608706304479_3_TH.jpg
#   inflating: ./data/val/talmo_2/8896_A2LEBJJDE001807_1607485134322_4_LH.jpg
#   inflating: ./data/val/talmo_2/8896_A2LEBJJDE001807_1607653693256_6_BH.jpg
#   inflating: ./data/val/talmo_2/8896_A2LEBJJDE001807_1607654804359_4_LH.jpg
#   inflating: ./data/val/talmo_2/9244_A2LEBJJDE00154W_1607590354436_4_LH.jpg
#   inflating: ./data/val/talmo_2/9244_A2LEBJJDE00154W_1607590387532_5_RH.jpg
#   inflating: ./data/val/talmo_2/9338_A2LEBJJDE00101D_1606742762533_2_TH.jpg
#   inflating: ./data/val/talmo_2/9527_A2LEBJJDE00110E_1606732870059_3_TH.jpg
#   inflating: ./data/val/talmo_2/9527_A2LEBJJDE00110E_1606741400034_3_TH.jpg
#   inflating: ./data/val/talmo_2/9578_A2LEBJJDE00105K_1608350762473_2_TH.jpg
#   inflating: ./data/val/talmo_2/0013_A2LEBJJDE00060O_1606706953049_2_TH.jpg
#   inflating: ./data/val/talmo_2/0616_A2LEBJJDE00004W_1606714826448_3_TH.jpg
#   inflating: ./data/val/talmo_2/0617_A2LEBJJDE000815_1606648650605_5_RH.jpg
#   inflating: ./data/val/talmo_2/0617_A2LEBJJDE000815_1606648950690_3_TH.jpg
#   inflating: ./data/val/talmo_2/0617_A2LEBJJDE000815_1606648950690_6_BH.jpg
#   inflating: ./data/val/talmo_2/0617_A2LEBJJDE000815_1606648969671_4_LH.jpg
#   inflating: ./data/val/talmo_2/0617_A2LEBJJDE000815_1606648969671_6_BH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711265640_2_TH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711265640_3_TH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711265640_5_RH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711265640_6_BH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711410681_3_TH.jpg
#   inflating: ./data/val/talmo_2/0643_A2LEBJJDE00048F_1606711433638_3_TH.jpg
#   inflating: ./data/val/talmo_2/0715_A2LEBJJDE00175D_1607495046489_3_TH.jpg
#   inflating: ./data/val/talmo_2/0715_A2LEBJJDE00175D_1607495151596_3_TH.jpg
#   inflating: ./data/val/talmo_2/0715_A2LEBJJDE00175D_1607495207485_3_TH.jpg
#   inflating: ./data/val/talmo_2/0715_A2LEBJJDE00175D_1607495445435_3_TH.jpg

# %% [markdown]
# # 인스톨 & 임포트

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->efficientnet_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (3.0.2)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16424 sha256=53d8cbbc4292a5b3ab9b118d9b2ca65543ca668ab1d876e061985da9aa98642b
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
import time
import datetime
import os
import copy
import cv2
import random
import numpy as np
import json
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.optim import lr_scheduler
from torchvision import transforms, datasets
from torch.utils.data import Dataset,DataLoader
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from PIL import Image
from efficientnet_pytorch import EfficientNet

# %%
from tqdm import tqdm  # tqdm 라이브러리 추가

# %%
import torch.nn.functional as F
import csv
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix

# %% [markdown]
# # 실행코드

# %% [markdown]
# ### Focal_loss

# %%
# Focal Loss 클래스 추가
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %% [markdown]
# ### 동적가중치+Focal_loss

# %%
class DynamicWeightedFocalLoss(nn.Module):
    def __init__(self, alpha=0.9, gamma=2, min_weight=0.5, max_weight=2.0, num_classes=3):
        super(DynamicWeightedFocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.min_weight = min_weight
        self.max_weight = max_weight
        self.num_classes = num_classes

        # GPU에서 클래스별 통계 초기화
        self.register_buffer('class_correct', torch.zeros(num_classes).cuda())
        self.register_buffer('class_total', torch.zeros(num_classes).cuda())
        self.register_buffer('class_weights', torch.ones(num_classes).cuda())

    def update_weights(self, preds, labels):
        with torch.no_grad():
            # GPU에서 직접 계산
            for label, pred in zip(labels, preds):
                self.class_total[label] += 1
                if label == pred:
                    self.class_correct[label] += 1

            # 클래스별 정확도 계산
            accuracies = torch.zeros_like(self.class_weights).cuda()
            mask = self.class_total > 0
            accuracies[mask] = self.class_correct[mask] / self.class_total[mask]

            # 정확도가 낮은 클래스에 더 높은 가중치 부여
            mean_acc = accuracies[mask].mean()
            new_weights = 1.0 + (mean_acc - accuracies)

            # 이동 평균 적용
            self.class_weights = self.alpha * self.class_weights + (1 - self.alpha) * new_weights

            # 가중치 범위 제한
            self.class_weights.clamp_(self.min_weight, self.max_weight)

    def forward(self, inputs, targets):
        # 예측된 클래스 구하기
        _, preds = torch.max(inputs, 1)

        # 학습 중일 때만 가중치 업데이트
        if self.training:
            self.update_weights(preds, targets)

        # focal loss 계산
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        # 클래스별 가중치 적용
        class_weights = self.class_weights[targets]  # 이미 GPU에 있으므로 직접 인덱싱
        weighted_focal_loss = class_weights * focal_loss

        return weighted_focal_loss.mean()

    def get_weights(self):
        return self.class_weights.clone()

# %%
# GPU 사용 가능 시 GPU, 아니면 CPU 사용
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
# 하이퍼파라미터 설정: 배치 사이즈와 랜덤 시드 설정
# 재현성을 위한 랜덤시드 고정
hyper_param_batch = 6
random_seed = 100
random.seed(random_seed)
torch.manual_seed(random_seed)

# %%
# 두피 증상에 대한 클래스 수 설정
num_classes = 3

# 사용할 EfficientNet 모델 이름과 훈련 데이터 폴더 설정
model_name = 'efficientnet-b1'
train_name = 'talmo_focal_cosine_dynamic_weight_01'

# 훈련된 모델 가중치를 저장할 경로 설정
PATH = '/content/drive/MyDrive/multi_scalp/scalp_weights/'

# %%
# 훈련, 검증, 테스트 데이터 경로 설정
data_train_path = './data/train'
data_validation_path = './data/val'
# data_test_path = './data/test'

# %%
# EfficientNet 모델에 맞는 입력 이미지 사이즈 가져오기
image_size = EfficientNet.get_image_size(model_name)
print(f'모델: {model_name}, 이미지 사이즈: {image_size}')
# Out:
# 모델: efficientnet-b1, 이미지 사이즈: 240

# %%
# EfficientNet 모델 불러오기 및 출력 클래스 수 설정
model = EfficientNet.from_pretrained(model_name, num_classes=num_classes)
model = model.to(device)
# Out:
# Loaded pretrained weights for efficientnet-b1

# %%
# 이미지 크기 조정 함수 추가
def resize_with_aspect_ratio(image, target_size):
    w, h = image.size
    aspect_ratio = w / h
    if aspect_ratio > 1:
        new_w = target_size
        new_h = int(target_size / aspect_ratio)
    else:
        new_h = target_size
        new_w = int(target_size * aspect_ratio)
    return image.resize((new_w, new_h), Image.BICUBIC)

# %%
# 데이터 증강 및 변환 설정 (훈련 데이터용)
transforms_train = transforms.Compose([
    transforms.Lambda(lambda img: resize_with_aspect_ratio(img, target_size=240)),
    transforms.RandomHorizontalFlip(p=0.5),  # 50% 확률로 좌우 반전
    transforms.RandomVerticalFlip(p=0.5),  # 50% 확률로 상하 반전
    transforms.Lambda(lambda x: x.rotate(90)),  # 90도 회전
    transforms.RandomRotation(10),  # 10도 이내에서 랜덤 회전
    transforms.ColorJitter(brightness=0.1, contrast=0.1),  # 컬러 색상 변경
    transforms.ToTensor(),  # 텐서로 변환
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 정규화
])

# 데이터 증강 및 변환 설정 (검증 데이터용)
transforms_val = transforms.Compose([
    transforms.Lambda(lambda img: resize_with_aspect_ratio(img, target_size=240)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 정규화
])

# %%
# 훈련 및 검증 데이터셋 불러오기
train_data_set = datasets.ImageFolder(data_train_path, transform=transforms_train)
val_data_set = datasets.ImageFolder(data_validation_path, transform=transforms_val)

# %%
# DataLoader 설정: 데이터를 배치로 나누고, 학습 및 검증 시 사용
dataloaders, batch_num = {}, {}
dataloaders['train'] = DataLoader(train_data_set, batch_size=hyper_param_batch, shuffle=True, num_workers=4)
dataloaders['val'] = DataLoader(val_data_set, batch_size=hyper_param_batch, shuffle=False, num_workers=4)

# %%
# 훈련 및 검증 데이터의 배치 수 계산
batch_num['train'], batch_num['val'] = len(train_data_set), len(val_data_set)

print('배치 크기: %d,  훈련/검증: %d / %d' % (hyper_param_batch, batch_num['train'], batch_num['val']))
# Out:
# 배치 크기: 6,  훈련/검증: 18513 / 5288

# %%
# 클래스 이름 출력 (예: 증상 종류)
class_names = train_data_set.classes
print(class_names)
# Out:
# ['talmo_0', 'talmo_1', 'talmo_2']

# %%
# 오분류 정보 저장 함수 추가
def save_misclassified(misclassified):
    save_path = '/content/drive/MyDrive/multi_scalp/misclassified/'
    os.makedirs(save_path, exist_ok=True)
    filename = os.path.join(save_path, f'all_misclassified_{train_name}.csv')
    with open(filename, 'w', newline='') as csvfile:
        fieldnames = ['epoch', 'filename', 'true_label', 'predicted_label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for item in misclassified:
            writer.writerow(item)
    print(f"All misclassified images information saved to {filename}")

# %% [markdown]
# ### 기존

# %%
# 모델 훈련 함수 정의
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    start_time = time.time()  # 시작 시간 기록
    since = time.time()
    best_acc = 0.0  # 최고 정확도 기록을 위한 변수
    best_model_wts = copy.deepcopy(model.state_dict())  # 최상의 모델 가중치 저장

    # 각 에포크별 손실 및 정확도 저장을 위한 리스트
    train_loss, train_acc, val_loss, val_acc = [], [], [], []
    all_misclassified = []

    # 에포크 수만큼 훈련 반복
    for epoch in range(num_epochs):
        print('에포크 {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        epoch_start = time.time()

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # 훈련 모드
            else:
                model.eval()  # 평가 모드

            running_loss = 0.0
            running_corrects = 0
            num_cnt = 0

            for inputs, labels in tqdm(dataloaders[phase]):  # 데이터 로드, tqdm 추가
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()  # 기울기 초기화

                with torch.set_grad_enabled(phase == 'train'):  # 학습 시 기울기 계산
                    outputs = model(inputs)  # 모델에 입력

                    _, preds = torch.max(outputs, 1)  # 예측값
                    loss = criterion(outputs, labels)  # 손실 계산

                    if phase == 'train':
                        loss.backward()  # 기울기 역전파
                        optimizer.step()  # 가중치 갱신

                running_loss += loss.item() * inputs.size(0)  # 손실 합산
                running_corrects += torch.sum(preds == labels.data)  # 정확도 계산
                num_cnt += len(labels)

                # 오분류 정보 수집 (검증 단계에서만)
                if phase == 'val':
                    for i in range(len(labels)):
                        if preds[i] != labels[i]:
                            all_misclassified.append({
                                'epoch': epoch,
                                'filename': val_data_set.samples[num_cnt - len(labels) + i][0],
                                'true_label': class_names[labels[i].item()],
                                'predicted_label': class_names[preds[i].item()]
                            })

            if phase == 'train':
                scheduler.step()  # 학습률 스케줄러 갱신

            # 에포크 손실 및 정확도 계산
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu() * 100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
                scheduler.step()  # 학습 단계 끝에 스케줄러 호출
            else:
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # 검증에서 최고 정확도일 경우 모델 저장
            if phase == 'val' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                print('==> 최고의 모델 저장 - %d / %.1f' % (best_idx, best_acc))

        # 현재 학습률 출력
        current_lr = optimizer.param_groups[0]['lr']
        print(f'Current Learning Rate: {current_lr:.6f}')

        epoch_end = time.time() - epoch_start
        print('Training epochs {} in {:.0f}m {:.0f}s'.format(epoch, epoch_end // 60, epoch_end % 60))
        print()

    # 훈련 완료 시간 출력
    time_elapsed = time.time() - start_time
    print('훈련 완료 시간: {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # 최고 성능 모델의 가중치 불러오기
    model.load_state_dict(best_model_wts)

    # 모델 및 가중치 저장
    torch.save(model, PATH + 'aram_'+train_name+'.pt')
    torch.save(model.state_dict(), PATH + 'president_aram_'+train_name+'.pt')
    print('모델 저장 완료')

    end_sec = time.time() - start_time
    end_times = str(datetime.timedelta(seconds=end_sec)).split('.')
    end_time = end_times[0]
    print("end time :", end_time)

    # 오분류 정보 저장
    save_misclassified(all_misclassified)

    return model, best_idx, best_acc, train_loss, train_acc, val_loss, val_acc

# %% [markdown]
# ### 신규

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25, save_path='./models/'):
    start_time = time.time()
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())

    # 훈련 통계 저장용 리스트
    train_loss, train_acc, val_loss, val_acc = [], [], [], []
    all_misclassified = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 30)

        epoch_start = time.time()

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            num_cnt = 0

            # 배치 단위 학습
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # 그래디언트 초기화
                optimizer.zero_grad()

                # forward pass
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward pass (학습 시에만)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        scheduler.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)

                # 검증 단계에서 오분류 정보 수집
                if phase == 'val':
                    for i in range(len(labels)):
                        if preds[i] != labels[i]:
                            all_misclassified.append({
                                'epoch': epoch,
                                'filename': val_data_set.samples[num_cnt - len(labels) + i][0],
                                'true_label': class_names[labels[i].item()],
                                'predicted_label': class_names[preds[i].item()]
                            })

            # 에포크 손실과 정확도 계산
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc = float((running_corrects.double() / num_cnt).cpu() * 100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)

                # 현재 학습률과 클래스 가중치 출력
                current_lr = optimizer.param_groups[0]['lr']
                current_weights = criterion.get_weights()
                print(f"Learning Rate: {current_lr:.6f}")
                print("Class weights:", current_weights.cpu().numpy())
            else:
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.2f}%')

            # 최고 성능 모델 저장
            if phase == 'val' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                # torch.save(model.state_dict(), f"{save_path}best_model_epoch_{epoch}.pt")
                print(f'==> 최고 성능 모델 저장 - Epoch {best_idx} / Acc {best_acc:.2f}%')

                # 모델 및 가중치 저장


        epoch_time = time.time() - epoch_start
        print(f'Epoch time: {epoch_time//60:.0f}m {epoch_time%60:.0f}s')
        print()

    # 학습 완료 시간 출력
    time_elapsed = time.time() - start_time
    print(f'Training complete in {time_elapsed//60:.0f}m {time_elapsed%60:.0f}s')
    print(f'Best val Acc: {best_acc:.2f}%')

    # 최고 성능 모델 로드
    model.load_state_dict(best_model_wts)

    # 최종 모델 저장
    torch.save(model, save_path + 'model_'+train_name+'.pt')
    torch.save(model.state_dict(), save_path + train_name +'weight.pt')
    print('모델 저장 완료')


    # 오분류 정보 저장 (기존 함수 사용)
    save_misclassified(all_misclassified)

    return model, best_idx, best_acc, train_loss, train_acc, val_loss, val_acc

# %%
# 손실 함수 및 옵티마이저 설정
# criterion = nn.CrossEntropyLoss()  # 기존 설정 주석 처리

# Focal Loss 사용
# criterion = FocalLoss(gamma=2)

# Loss function
criterion = DynamicWeightedFocalLoss(
    alpha=0.9,
    gamma=2.0,
    num_classes=len(class_names)
)


optimizer_ft = optim.Adam(model.parameters(), lr=1e-3)

# %%
# CosineAnnealingLR 스케줄러 설정
num_epochs = 5
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer_ft, T_max=len(dataloaders['train']) * num_epochs, eta_min=1e-6)

# %%
# 에포크 수 설정하고 훈련 시작
train_model(model, criterion, optimizer_ft,scheduler, num_epochs=num_epochs, save_path=PATH)
# Out:
# Epoch 0/4
# ------------------------------
# 100%|██████████| 3086/3086 [03:29<00:00, 14.70it/s]
# Learning Rate: 0.000905
# Class weights: [1.2408438 0.5204391 1.2387166]
# train Loss: 0.0939 Acc: 89.33%
# 100%|██████████| 882/882 [00:23<00:00, 38.17it/s]
# val Loss: 0.0594 Acc: 86.72%
# ==> 최고 성능 모델 저장 - Epoch 0 / Acc 86.72%
# Epoch time: 3m 53s
#
# Epoch 1/4
# ------------------------------
# 100%|██████████| 3086/3086 [03:31<00:00, 14.61it/s]
# Learning Rate: 0.000655
# Class weights: [1.191655   0.57981956 1.2285246 ]
# train Loss: 0.0785 Acc: 91.42%
# 100%|██████████| 882/882 [00:23<00:00, 38.13it/s]
# val Loss: 0.0887 Acc: 79.27%
# Epoch time: 3m 54s
#
# Epoch 2/4
# ------------------------------
# 100%|██████████| 3086/3086 [03:29<00:00, 14.71it/s]
# Learning Rate: 0.000346
# Class weights: [1.1436516 0.6201712 1.2361765]
# train Loss: 0.0665 Acc: 92.76%
# 100%|██████████| 882/882 [00:22<00:00, 38.72it/s]
# val Loss: 0.0551 Acc: 90.71%
# ==> 최고 성능 모델 저장 - Epoch 2 / Acc 90.71%
# Epoch time: 3m 53s
#
# Epoch 3/4
# ------------------------------
# 100%|██████████| 3086/3086 [03:29<00:00, 14.74it/s]
# Learning Rate: 0.000096
# Class weights: [1.116438  0.6382626 1.2452985]
# train Loss: 0.0602 Acc: 93.42%
# 100%|██████████| 882/882 [00:22<00:00, 38.88it/s]
# val Loss: 0.0449 Acc: 93.36%
# ==> 최고 성능 모델 저장 - Epoch 3 / Acc 93.36%
# Epoch time: 3m 52s
#
# Epoch 4/4
# ------------------------------
# 100%|██████████| 3086/3086 [03:32<00:00, 14.55it/s]
# Learning Rate: 0.000001
# Class weights: [1.1036558 0.6548758 1.2414678]
# train Loss: 0.0547 Acc: 93.93%
# 100%|██████████| 882/882 [00:22<00:00, 38.69it/s]
# val Loss: 0.0446 Acc: 93.48%
# ==> 최고 성능 모델 저장 - Epoch 4 / Acc 93.48%
# Epoch time: 3m 55s
#
# Training complete in 19m 27s
# Best val Acc: 93.48%
# 모델 저장 완료
# All misclassified images information saved to /content/drive/MyDrive/multi_scalp/misclassified/all_misclassified_talmo_focal_cosine_dynamic_weight_01.csv
# (EfficientNet(
#    (_conv_stem): Conv2dStaticSamePadding(
#      3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#      (static_padding): ZeroPad2d((0, 1, 0, 1))
#    )
#    (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_blocks): ModuleList(
#      (0): MBConvBlock(
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          32, 8, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          8, 32, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (1): MBConvBlock(
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          16, 16, kernel_size=(3, 3), stride=(1, 1), groups=16, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          16, 4, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          4, 16, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (2): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#          (static_padding): ZeroPad2d((0, 1, 0, 1))
#        )
#        (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          96, 4, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          4, 96, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (3-4): 2 x MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          144, 6, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          6, 144, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (5): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#          (static_padding): ZeroPad2d((1, 2, 1, 2))
#        )
#        (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          144, 6, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          6, 144, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (6-7): 2 x MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#          (static_padding): ZeroPad2d((2, 2, 2, 2))
#        )
#        (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          240, 10, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          10, 240, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (8): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#          (static_padding): ZeroPad2d((0, 1, 0, 1))
#        )
#        (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          240, 10, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          10, 240, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (9-11): 3 x MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          480, 20, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          20, 480, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (12): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#          (static_padding): ZeroPad2d((2, 2, 2, 2))
#        )
#        (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          480, 20, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          20, 480, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (13-15): 3 x MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#          (static_padding): ZeroPad2d((2, 2, 2, 2))
#        )
#        (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          672, 28, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          28, 672, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (16): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#          (static_padding): ZeroPad2d((2, 2, 2, 2))
#        )
#        (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          672, 28, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          28, 672, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (17-20): 4 x MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#          (static_padding): ZeroPad2d((2, 2, 2, 2))
#        )
#        (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          1152, 48, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          48, 1152, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (21): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          1152, 48, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          48, 1152, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#      (22): MBConvBlock(
#        (_expand_conv): Conv2dStaticSamePadding(
#          320, 1920, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn0): BatchNorm2d(1920, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_depthwise_conv): Conv2dStaticSamePadding(
#          1920, 1920, kernel_size=(3, 3), stride=(1, 1), groups=1920, bias=False
#          (static_padding): ZeroPad2d((1, 1, 1, 1))
#        )
#        (_bn1): BatchNorm2d(1920, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_se_reduce): Conv2dStaticSamePadding(
#          1920, 80, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_se_expand): Conv2dStaticSamePadding(
#          80, 1920, kernel_size=(1, 1), stride=(1, 1)
#          (static_padding): Identity()
#        )
#        (_project_conv): Conv2dStaticSamePadding(
#          1920, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#          (static_padding): Identity()
#        )
#        (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#        (_swish): MemoryEfficientSwish()
#      )
#    )
#    (_conv_head): Conv2dStaticSamePadding(
#      320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#    (_dropout): Dropout(p=0.2, inplace=False)
#    (_fc): Linear(in_features=1280, out_features=3, bias=True)
#    (_swish): MemoryEfficientSwish()
#  ),
#  4,
#  93.47579425113464,
#  [0.09391629757414559,
#   0.07854124907949908,
#   0.06650498556252372,
#   0.06021778163515373,
#   0.054717512721981505],
#  [89.33182088262302,
#   91.42224382866094,
#   92.76184302922272,
#   93.42083941014423,
#   93.93399232971426],
#  [0.059422530810564964,
#   0.0887423282837546,
#   0.055077090555077785,
#   0.04491947001619786,
#   0.04464165393255],
#  [86.72465960665659,
#   79.27382753403933,
#   90.71482602118003,
#   93.3623298033283,
#   93.47579425113464])

# %% [markdown]
# ### 모델 테스트

# %%
import torch
import os
import csv
from torchvision import transforms
from PIL import Image

# GPU 사용 여부 확인
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 모델 불러오기 (저장된 모델 경로 사용)
model = torch.load("/content/drive/MyDrive/multi_scalp/scalp_weights/modeltalmo_focal_cosine_dynamic_weight_01.pt")  # 모델 경로 수정
model = model.to(device)
model.eval()  # 평가 모드로 전환

# 이미지 전처리 설정
transform = transforms.Compose([
    transforms.Resize((240, 240)),  # 모델 입력 크기에 맞게 조정
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 이미지 정규화
])
# Out:
# <ipython-input-46-e04031d74521>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load("/content/drive/MyDrive/multi_scalp/scalp_weights/modeltalmo_focal_cosine_dynamic_weight_01.pt")  # 모델 경로 수정

# %%
# 이미지가 저장된 폴더 경로 설정
image_folder = '/content/data/val/talmo_2'  # 이미지 폴더 경로 수정

# 결과를 저장할 CSV 파일 경로
csv_file = '/content/drive/MyDrive/multi_scalp/test_result/talmo_val2_dynamic_weight_probabilities_01.csv'

# 클래스 이름 (모델이 학습한 클래스 이름을 사용)
class_names = ['class_0', 'class_1', 'class_2']  # 클래스 이름 수정

# CSV 파일을 만들기 위한 설정
header = ['image', 'top_class', 'top_probability', 'second_class', 'second_probability']  # 헤더 설정

# %%
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)  # 헤더 작성

    # 이미지 폴더의 모든 파일에 대해 예측
    for image_name in os.listdir(image_folder):
        if image_name.endswith(('.png', '.jpg', '.jpeg')):  # 이미지 파일 확장자 필터링
            image_path = os.path.join(image_folder, image_name)

            # 이미지 불러오기
            image = Image.open(image_path).convert('RGB')  # 이미지를 RGB로 변환
            image = transform(image).unsqueeze(0).to(device)  # 이미지 전처리 및 배치 추가

            # 모델에 입력하여 클래스별 확률 계산
            with torch.no_grad():  # 평가 모드에서 기울기 계산 방지
                outputs = model(image)
                probabilities = torch.nn.functional.softmax(outputs, dim=1)  # softmax로 확률 변환

            # 각 이미지에 대한 클래스별 확률값 저장
            prob_values = probabilities.cpu().numpy()[0]  # 확률값을 numpy 배열로 변환

            # 상위 두 개의 확률 및 해당 클래스 찾기
            top_two_indices = prob_values.argsort()[-2:][::-1]  # 상위 2개의 인덱스 (내림차순)
            top_class = class_names[top_two_indices[0]]  # 첫 번째 클래스
            top_probability = prob_values[top_two_indices[0]]  # 첫 번째 확률
            second_class = class_names[top_two_indices[1]]  # 두 번째 클래스
            second_probability = prob_values[top_two_indices[1]]  # 두 번째 확률

            # 이미지 이름과 상위 두 클래스, 확률을 CSV로 저장
            row = [image_name, top_class, top_probability, second_class, second_probability]
            writer.writerow(row)

# %%
# 그리드 탐색 (최적의 하이퍼파라미터 값 찾기)

import torch
import torch.optim as optim
from efficientnet_pytorch import EfficientNet

# 탐색할 하이퍼파라미터 목록
learning_rates = [1e-4, 1e-3, 1e-2]
t_max_values = [5, 10, 20]
eta_min_values = [1e-6, 1e-5]

best_acc = 0.0
best_hyperparams = {}

for lr in learning_rates:
    for t_max in t_max_values:
        for eta_min in eta_min_values:
            print(f"Training with lr={lr}, T_max={t_max}, eta_min={eta_min}")

            # 모델 초기화
            model = EfficientNet.from_pretrained('efficientnet-b1', num_classes=3)
            model = model.to(device)

            # 옵티마이저 및 스케줄러 설정
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=t_max, eta_min=eta_min)

            # 훈련 시작 (train_model 함수로 대체)
            model, _, epoch_acc, _, _, _, _ = train_model(model, criterion, optimizer, scheduler, num_epochs=5)

            # 최적 성능 저장
            if epoch_acc > best_acc:
                best_acc = epoch_acc
                best_hyperparams = {'lr': lr, 'T_max': t_max, 'eta_min': eta_min}

print(f"Best accuracy: {best_acc}")
print(f"Best hyperparameters: {best_hyperparams}")
# Out:
# Training with lr=0.0001, T_max=5, eta_min=1e-06
# Loaded pretrained weights for efficientnet-b1
# 에포크 0/4
# ----------
# 100%|██████████| 625/625 [01:19<00:00,  7.89it/s]
# train Loss: 0.1725 Acc: 82.0000
# 100%|██████████| 179/179 [00:12<00:00, 14.79it/s]
# val Loss: 0.2014 Acc: 78.0374
# ==> 최고의 모델 저장 - 0 / 78.0
# Current Learning Rate: 0.000066
# Training epochs 0 in 1m 31s
#
# 에포크 1/4
# ----------
# 100%|██████████| 625/625 [01:18<00:00,  7.93it/s]
# train Loss: 0.1082 Acc: 87.2533
# 100%|██████████| 179/179 [00:12<00:00, 14.56it/s]
# val Loss: 0.1560 Acc: 80.3738
# ==> 최고의 모델 저장 - 1 / 80.4
# Current Learning Rate: 0.000010
# Training epochs 1 in 1m 31s
#
# 에포크 2/4
# ----------
# 100%|██████████| 625/625 [01:17<00:00,  8.02it/s]
# train Loss: 0.0920 Acc: 88.8267
# 100%|██████████| 179/179 [00:11<00:00, 15.12it/s]
# val Loss: 0.1495 Acc: 81.3084
# ==> 최고의 모델 저장 - 2 / 81.3
# Current Learning Rate: 0.000010
# Training epochs 2 in 1m 30s
#
# 에포크 3/4
# ----------
# 100%|██████████| 625/625 [01:17<00:00,  8.02it/s]
# train Loss: 0.0839 Acc: 89.5467
# 100%|██████████| 179/179 [00:12<00:00, 14.79it/s]
# val Loss: 0.1475 Acc: 82.4299
# ==> 최고의 모델 저장 - 3 / 82.4
# Current Learning Rate: 0.000066
# Training epochs 3 in 1m 30s
#
# 에포크 4/4
# ----------
# 100%|██████████| 625/625 [01:17<00:00,  8.05it/s]
# train Loss: 0.0880 Acc: 88.2933
# 100%|██████████| 179/179 [00:14<00:00, 12.06it/s]
# val Loss: 0.1228 Acc: 85.3271
# ==> 최고의 모델 저장 - 4 / 85.3
# Current Learning Rate: 0.000100
# Training epochs 4 in 1m 33s
#
# 훈련 완료 시간: 7m 35s
# Best valid Acc: 4 - 85.3
# 모델 저장 완료
# end time : 0:07:35
# All misclassified images information saved to ./drive/MyDrive/241122_final_project/data/error(efficientnet_b1_focal-loss_cosine_lr=1e-3_class-3)/all_misclassified.csv
# Training with lr=0.0001, T_max=5, eta_min=1e-05
# Loaded pretrained weights for efficientnet-b1
# 에포크 0/4
# ----------
# 100%|██████████| 625/625 [01:30<00:00,  6.94it/s]
# train Loss: 0.1736 Acc: 81.0400
# 100%|██████████| 179/179 [00:17<00:00, 10.16it/s]
# val Loss: 0.2038 Acc: 76.4486
# ==> 최고의 모델 저장 - 0 / 76.4
# Current Learning Rate: 0.000069
# Training epochs 0 in 1m 48s
#
# 에포크 1/4
# ----------
# 100%|██████████| 625/625 [01:33<00:00,  6.69it/s]
# train Loss: 0.1071 Acc: 87.0667
# 100%|██████████| 179/179 [00:15<00:00, 11.56it/s]
# val Loss: 0.1549 Acc: 80.5607
# ==> 최고의 모델 저장 - 1 / 80.6
# Current Learning Rate: 0.000019
# Training epochs 1 in 1m 49s
#
# 에포크 2/4
# ----------
# 100%|██████████| 625/625 [01:27<00:00,  7.17it/s]
# train Loss: 0.0951 Acc: 88.2133
# 100%|██████████| 179/179 [00:17<00:00, 10.15it/s]
# val Loss: 0.1428 Acc: 82.0561
# ==> 최고의 모델 저장 - 2 / 82.1
# Current Learning Rate: 0.000019
# Training epochs 2 in 1m 45s
#
# 에포크 3/4
# ----------
# 100%|██████████| 625/625 [01:31<00:00,  6.82it/s]
# train Loss: 0.0835 Acc: 89.4400
# 100%|██████████| 179/179 [00:18<00:00,  9.81it/s]
# val Loss: 0.1345 Acc: 81.4019
# Current Learning Rate: 0.000069
# Training epochs 3 in 1m 50s
#
# 에포크 4/4
# ----------
# 100%|██████████| 625/625 [01:29<00:00,  6.99it/s]
# train Loss: 0.0891 Acc: 88.6933
# 100%|██████████| 179/179 [00:18<00:00,  9.67it/s]
# val Loss: 0.1254 Acc: 83.8318
# ==> 최고의 모델 저장 - 4 / 83.8
# Current Learning Rate: 0.000100
# Training epochs 4 in 1m 48s
#
# 훈련 완료 시간: 8m 60s
# Best valid Acc: 4 - 83.8
# 모델 저장 완료
# end time : 0:09:00
# All misclassified images information saved to ./drive/MyDrive/241122_final_project/data/error(efficientnet_b1_focal-loss_cosine_lr=1e-3_class-3)/all_misclassified.csv
# Training with lr=0.0001, T_max=10, eta_min=1e-06
# Loaded pretrained weights for efficientnet-b1
# 에포크 0/4
# ----------
# 100%|██████████| 625/625 [01:34<00:00,  6.64it/s]
# train Loss: 0.1697 Acc: 82.0000
# 100%|██████████| 179/179 [00:17<00:00, 10.41it/s]
# val Loss: 0.1638 Acc: 80.6542
# ==> 최고의 모델 저장 - 0 / 80.7
# Current Learning Rate: 0.000091
# Training epochs 0 in 1m 51s
#
# 에포크 1/4
# ----------
# 100%|██████████| 625/625 [01:30<00:00,  6.94it/s]
# train Loss: 0.1066 Acc: 86.9333
# 100%|██████████| 179/179 [00:17<00:00, 10.07it/s]
# val Loss: 0.1035 Acc: 88.1308
# ==> 최고의 모델 저장 - 1 / 88.1
# Current Learning Rate: 0.000066
# Training epochs 1 in 1m 48s
#
# 에포크 2/4
# ----------
# 100%|██████████| 625/625 [01:32<00:00,  6.79it/s]
# train Loss: 0.0937 Acc: 88.0533
# 100%|██████████| 179/179 [00:17<00:00, 10.19it/s]
# val Loss: 0.1157 Acc: 85.7944
# Current Learning Rate: 0.000035
# Training epochs 2 in 1m 50s
#
# 에포크 3/4
# ----------
# 100%|██████████| 625/625 [01:28<00:00,  7.04it/s]
# train Loss: 0.0789 Acc: 90.1600
# 100%|██████████| 179/179 [00:18<00:00,  9.82it/s]
# val Loss: 0.1095 Acc: 86.5421
# Current Learning Rate: 0.000010
# Training epochs 3 in 1m 47s
#
# 에포크 4/4
# ----------
# 100%|██████████| 625/625 [01:32<00:00,  6.79it/s]
# train Loss: 0.0699 Acc: 91.0933
# 100%|██████████| 179/179 [00:18<00:00,  9.89it/s]
# val Loss: 0.1034 Acc: 87.1028
# Current Learning Rate: 0.000001
# Training epochs 4 in 1m 50s
#
# 훈련 완료 시간: 9m 6s
# Best valid Acc: 1 - 88.1
# 모델 저장 완료
# end time : 0:09:06
# All misclassified images information saved to ./drive/MyDrive/241122_final_project/data/error(efficientnet_b1_focal-loss_cosine_lr=1e-3_class-3)/all_misclassified.csv
# Training with lr=0.0001, T_max=10, eta_min=1e-05
# Loaded pretrained weights for efficientnet-b1
# 에포크 0/4
# ----------
# 100%|██████████| 625/625 [01:29<00:00,  7.02it/s]
# train Loss: 0.1674 Acc: 81.5467
# 100%|██████████| 179/179 [00:16<00:00, 10.81it/s]
# val Loss: 0.1363 Acc: 85.7944
# ==> 최고의 모델 저장 - 0 / 85.8
# Current Learning Rate: 0.000091
# Training epochs 0 in 1m 46s
#
# 에포크 1/4
# ----------
# 100%|██████████| 625/625 [01:32<00:00,  6.76it/s]
# train Loss: 0.1068 Acc: 85.8400
# 100%|██████████| 179/179 [00:17<00:00, 10.02it/s]
# val Loss: 0.1516 Acc: 81.4019
# Current Learning Rate: 0.000069
# Training epochs 1 in 1m 50s
#
# 에포크 2/4
# ----------
# 100%|██████████| 625/625 [01:30<00:00,  6.91it/s]
# train Loss: 0.0950 Acc: 88.8800
# 100%|██████████| 179/179 [00:17<00:00, 10.05it/s]
# val Loss: 0.1355 Acc: 83.6449
# Current Learning Rate: 0.000041
# Training epochs 2 in 1m 48s
#
# 에포크 3/4
# ----------
# 100%|██████████| 625/625 [01:33<00:00,  6.66it/s]
# train Loss: 0.0771 Acc: 90.0267
# 100%|██████████| 179/179 [00:17<00:00, 10.45it/s]
# val Loss: 0.1239 Acc: 85.3271
# Current Learning Rate: 0.000019
# Training epochs 3 in 1m 51s
#
# 에포크 4/4
# ----------
# 100%|██████████| 625/625 [01:28<00:00,  7.07it/s]
# train Loss: 0.0707 Acc: 90.3200
# 100%|██████████| 179/179 [00:17<00:00, 10.12it/s]
# val Loss: 0.1195 Acc: 85.5140
# Current Learning Rate: 0.000010
# Training epochs 4 in 1m 46s
#
# 훈련 완료 시간: 9m 1s
# Best valid Acc: 0 - 85.8
# 모델 저장 완료
# end time : 0:09:01
# All misclassified images information saved to ./drive/MyDrive/241122_final_project/data/error(efficientnet_b1_focal-loss_cosine_lr=1e-3_class-3)/all_misclassified.csv
# Training with lr=0.0001, T_max=20, eta_min=1e-06
# Loaded pretrained weights for efficientnet-b1
# 에포크 0/4
# ----------
# 100%|██████████| 625/625 [01:34<00:00,  6.64it/s]
# train Loss: 0.1699 Acc: 81.1200
# 100%|██████████| 179/179 [00:17<00:00, 10.45it/s]
# val Loss: 0.1833 Acc: 76.0748
# ==> 최고의 모델 저장 - 0 / 76.1
# Current Learning Rate: 0.000098
# Training epochs 0 in 1m 51s
#
# 에포크 1/4
# ----------
#  17%|█▋        | 104/625 [00:14<01:13,  7.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-80584213ee1d> in <cell line: 13>()
#      25
#      26             # 훈련 시작 (train_model 함수로 대체)
# ---> 27             model, _, epoch_acc, _, _, _, _ = train_model(model, criterion, optimizer, scheduler, num_epochs=5)
#      28
#      29             # 최적 성능 저장
#
# <ipython-input-44-d0ab20cc72e6> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      40
#      41                     if phase == 'train':
# ---> 42                         loss.backward()  # 기울기 역전파
#      43                         optimizer.step()  # 가중치 갱신
#      44
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     519                 inputs=inputs,
#     520             )
# --> 521         torch.autograd.backward(
#     522             self, gradient, retain_graph, create_graph, inputs=inputs
#     523         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     287     # some Python versions print out the first line of a multi-line function
#     288     # calls in the traceback and some print out the last line
# --> 289     _engine_run_backward(
#     290         tensors,
#     291         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     767         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768     try:
# --> 769         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770             t_outputs, *args, **kwargs
#     771         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
